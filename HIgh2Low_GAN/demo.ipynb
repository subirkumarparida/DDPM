# %%
import pickle

# %%
# Input Data
my_data = { 'BMW', 'Audi', 'Toyota', 'Benz'}

# Pickle the input
with open("demo.pickle","wb") as file_handle:
    pickle.dump(my_data, file_handle, pickle.HIGHEST_PROTOCOL)

# %%
# Unpickle the above pickled file
with open("demo.pickle","rb") as file_handle:
 res = pickle.load(file_handle)
 print(res) # display the output
# Out:
# {'BMW', 'Toyota', 'Benz', 'Audi'}

# %%
# Unpickle the above pickled file
with open("model_yoon.pkl","rb") as file_handle:
    res = pickle.load(file_handle)
    print(res) # display the output
# Out:
# 119547037146038801333356

# %%
with open('model_yoon.pkl', 'rb') as handle:
    serialized = handle.read()

# %%
b = pickle.loads(serialized)
print(b.discriminator_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_21221/2315968009.py in <module>
#       1 b = pickle.loads(serialized)
# ----> 2 print(b.discriminator_test)
#
# AttributeError: 'int' object has no attribute 'discriminator_test'

# %%
loaded_model = pickle.load(open("model.pkl", 'rb'))

# %%
loaded_model
# Out:
# 119547037146038801333356

# %%
loaded_model['BasicBlock_Gen']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_21221/659019240.py in <module>
# ----> 1 loaded_model['BasicBlock_Gen']
#
# TypeError: 'int' object is not subscriptable
