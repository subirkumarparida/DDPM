# %%
import os
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mpl
from matplotlib import rcParams
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import LinearSegmentedColormap, ListedColormap

# %%
fig, ax = plt.subplots()

start = 0
never = 54
seldom = 43
undecided = 3

start = 0
White = 83
Indian = 5
Black = 7
Asian = 5

#ax.broken_barh([(start, never), (never, never+seldom), (never+seldom, never+seldom+undecided)], [10, 9], facecolors=('#6259D8', '#E53F08', '#FDB200'))
ax.broken_barh([(start, White), (White, White+Indian), (White+Indian, White+Indian+Black), 
                (White+Indian+Black, White+Indian+Black+Asian)], [12, 15], 
               facecolors=('#6259D8', '#E53F08', '#FDB200', '#6259A8'))

ax.set_ylim(5, 15)
ax.set_xlim(0, 100)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_yticks([15, 25])
ax.set_yticklabels(['Geeks1', 'Geeks2'])

ax.set_xticks([0, 25, 50, 75, 100])
ax.set_axisbelow(True) 

ax.grid(axis='x')
ax.text(White-6, 14.5, "54%", fontsize=8)
ax.text((White+Indian)-6, 14.5, "43%", fontsize=8)
ax.text((White+Indian+Black)+2, 14.5, "3%", fontsize=8)
ax.text((White+Indian+Black+Asian)+2, 14.5, "3%", fontsize=8)

fig.suptitle('Race variations', fontsize=10)

leg1 = mpatches.Patch(color='#6259D8', label='White')
leg2 = mpatches.Patch(color='#E53F08', label='Indian')
leg3 = mpatches.Patch(color='#FDB200', label='Black')
leg4 = mpatches.Patch(color='#6259A8', label='Asian')
ax.legend(handles=[leg1, leg2, leg3, leg4], ncol=4)

plt.show()
