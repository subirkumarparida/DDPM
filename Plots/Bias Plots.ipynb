# %%
import os
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mpl
from matplotlib import rcParams
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import LinearSegmentedColormap, ListedColormap

# %%
mpl.rcParams['savefig.dpi'] = 300

# %%
#!pip install odfpy --proxy=http://subirkp:Sbr%25hbni01@192.168.2.16:8080
#!pip install odfpy

# %%
#sb.barplot?

# %%
#sb.set_style("whitegrid")
#sb.set_style("white")
#sb.set_palette("husl")

# %%
dir_name = 'fig'
if not os.path.exists(dir_name):
    os.makedirs(dir_name)

# %% [markdown]
# # CelebA-HQ

# %%
df_celeb_race = pd.read_excel('Book.ods', 'CelebA-race')

# %%
#df

# %%
rcParams['figure.figsize'] = 8, 5

ax = sb.barplot(x = "Race", y = "generation in percentage", hue = "Dataset", 
                data = df_celeb_race, palette=sb.color_palette("light:#5A9", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)
    
#sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/celeb_race.pdf')

# %%
rcParams['figure.figsize'] = 8, 5

df_celeb_gender = pd.read_excel('Book.ods', 'CelebA-gender')

ax = sb.barplot(x = "Gender", y = "generation in percentage", hue = "Dataset", 
                data = df_celeb_gender, palette=sb.color_palette("light:#5A9", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)
    
#sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/celeb_gender.pdf')

# %%
rcParams['figure.figsize'] = 10, 6

df_celeb_age = pd.read_excel('Book.ods', 'CelebA-age')

ax = sb.barplot(x = "Age", y = "generation in percentage", hue = "Dataset", 
                data = df_celeb_age, palette=sb.color_palette("light:#5A9", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)
    
#sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/celeb_age.pdf')

# %% [markdown]
# # Fairface

# %%
rcParams['figure.figsize'] = 8, 5

df_fairface_race = pd.read_excel('Book.ods', 'Fairface-race')

ax = sb.barplot(x = "Race", y = "generation in percentage", hue = "Dataset", 
                data = df_fairface_race, palette=sb.color_palette("light:#5A9", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)

#sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/fairface_race.pdf')

# %%
# df_fairface_race = pd.read_excel('Book.ods', 'Fairface-race')

# ax = sb.barplot(x = "Dataset", y = "pctage", hue = "Race", 
#                 data = df_fairface_race, palette=sb.color_palette("BrBG", 4))
# #plt.show()
# for i in ax.containers:
#     ax.bar_label(i,)

# %%
rcParams['figure.figsize'] = 8, 5

df_fairface_gender = pd.read_excel('Book.ods', 'Fairface-gender')

ax = sb.barplot(x = "Gender", y = "generation in percentage", hue = "Dataset", 
                data = df_fairface_gender, palette=sb.color_palette("light:#5A9", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)
    
sb.move_legend(ax, "lower center") #, bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/fairface_gender.pdf')

# %%
rcParams['figure.figsize'] = 10, 6

df_fairface_age = pd.read_excel('Book.ods', 'Fairface-age')

ax = sb.barplot(x = "Age", y = "generation in percentage", hue = "Dataset", 
                data = df_fairface_age, palette=sb.color_palette("light:#5A9", 4))

#plt.show()
for i in ax.containers:
    ax.bar_label(i,)

#ax.get_legend().remove()
ax.figure.savefig('fig/fairface_age.pdf')

# %% [markdown]
# # Fairface - Balanced

# %%
rcParams['figure.figsize'] = 8, 5

df_fairface_race_bal = pd.read_excel('Book.ods', 'FairfaceBal-race')

ax = sb.barplot(x = "Race", y = "generation in percentage", hue = "Dataset", 
                data = df_fairface_race_bal, palette=sb.color_palette("light:#5A9", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)
    
#sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/fairface_race_bal.pdf')

# %%
rcParams['figure.figsize'] = 8, 5

df_fairface_gender_bal = pd.read_excel('Book.ods', 'FairfaceBal-gender')

ax = sb.barplot(x = "Gender", y = "generation in percentage", hue = "Dataset", 
                data = df_fairface_gender_bal, palette=sb.color_palette("light:#5A9", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)
    
#sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/fairface_gender_bal.pdf')

# %%
rcParams['figure.figsize'] = 10, 6

df_fairface_age_bal = pd.read_excel('Book.ods', 'FairfaceBal-age')

ax = sb.barplot(x = "Age", y = "generation in percentage", hue = "Dataset", 
                data = df_fairface_age_bal, palette=sb.color_palette("light:#5A9", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)

#ax.get_legend().remove()
ax.figure.savefig('fig/fairface_age_bal.pdf')

# %% [markdown]
# # DDPM

# %%
rcParams['figure.figsize'] = 8, 5

df_ddpm_race = pd.read_excel('Book.ods', 'DDPM')

ax = sb.barplot(x = "Race", y = "generation in percentage", hue = "Dataset", 
                data = df_ddpm_race, palette=sb.color_palette("GnBu", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)

#sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/ddpm_race.pdf')

# %% [markdown]
# # DDGAN

# %%
rcParams['figure.figsize'] = 8, 5

df_ddgan_race = pd.read_excel('Book.ods', 'DDGAN')

ax = sb.barplot(x = "Race", y = "generation in percentage", hue = "Dataset", 
                data = df_ddgan_race, palette=sb.color_palette("GnBu", 4))
#plt.show()
for i in ax.containers:
    ax.bar_label(i,)

#sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#ax.get_legend().remove()
ax.figure.savefig('fig/ddgan_race.pdf')

# %%
rcParams['figure.figsize'] = 8, 5

df_celeb = pd.read_excel('Racial-Gender-Imbalance.xlsx', 'CelebA-HQ') #, index_col=[0, 1])
df_celeb = df_celeb.groupby(["Race", "Dataset"]).agg(generation_in_percentage=("generation in percentage", 'mean'))
df_celeb
# Out:
#                    generation_in_percentage
# Race   Dataset
# Asian  DDGAN                           1.00
#        DDPM                            2.55
#        LDM                             1.50
#        Train data                      2.35
# Black  DDGAN                           3.00
#        DDPM                            1.85
#        LDM                             2.15
#        Train data                      3.35
# Indian DDGAN                           5.05
#        DDPM                            1.05
#        LDM                             1.05
#        Train data                      2.35
# White  DDGAN                          40.95
#        DDPM                           44.60
#        LDM                            45.35
#        Train data                     41.85

# %%
df_celeb = df_celeb.reset_index()
df_celeb
# Out:
#       Race     Dataset  generation_in_percentage
# 0    Asian       DDGAN                      1.00
# 1    Asian        DDPM                      2.55
# 2    Asian         LDM                      1.50
# 3    Asian  Train data                      2.35
# 4    Black       DDGAN                      3.00
# 5    Black        DDPM                      1.85
# 6    Black         LDM                      2.15
# 7    Black  Train data                      3.35
# 8   Indian       DDGAN                      5.05
# 9   Indian        DDPM                      1.05
# 10  Indian         LDM                      1.05
# 11  Indian  Train data                      2.35
# 12   White       DDGAN                     40.95
# 13   White        DDPM                     44.60
# 14   White         LDM                     45.35
# 15   White  Train data                     41.85

# %%
#df_celeb.set_index(['Race', 'Dataset', 'Gender']).plot(kind='bar', stacked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12960\2699897188.py in ?()
# ----> 1 df_celeb.set_index(['Race', 'Dataset', 'Gender']).plot(kind='bar', stacked=True)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['Gender'] are in the columns"

# %%
rcParams['figure.figsize'] = 8, 5

df_celeb_race = pd.read_excel('Book.ods', 'CelebA-race')
df_race = df_celeb_race[df_celeb_race["Dataset"] == "Train data"]

labels = df_race["Race"]
sizes = df_race["generation in percentage"]

color_pallete = ['peachpuff', 'lemonchiffon', 'lavender', 'lavenderblush']

explode = (0, 0.1, 0.1, 0.1)

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, 
       colors=color_pallete)
# ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', pctdistance=1.15, labeldistance=.7,
#        shadow=True, startangle=90, colors=['lightgray', 'mistyrose', 'mintcream', 'lavender'])

plt.show()
ax.figure.savefig('fig/a.pdf')

# %%
df_celeb_race = pd.read_excel('Book.ods', 'CelebA-race')

df_race1 = df_celeb_race[df_celeb_race["Dataset"] == "Train data"]
labels1 = df_race1["Race"]
sizes1 = df_race1["generation in percentage"]

df_race2 = df_celeb_race[df_celeb_race["Dataset"] == "DDPM"]
labels2 = df_race2["Race"]
sizes2 = df_race2["generation in percentage"]

df_race3 = df_celeb_race[df_celeb_race["Dataset"] == "DDGAN"]
labels3 = df_race3["Race"]
sizes3 = df_race3["generation in percentage"]

df_race4 = df_celeb_race[df_celeb_race["Dataset"] == "LDM"]
labels4 = df_race4["Race"]
sizes4 = df_race4["generation in percentage"]

color_pallete = ['peachpuff', 'lemonchiffon', 'lavender', 'lavenderblush']

# %%
fig = plt.figure(figsize=(18,10), dpi=1600)
#2 rows 2 columns

ax1 = plt.subplot2grid((1,4), (0,0))
plt.pie(sizes1, labels=labels1, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)
#plt.title('Train')

ax2 = plt.subplot2grid((1,4), (0,1))
plt.pie(sizes2, labels=labels2, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

ax3 = plt.subplot2grid((1,4), (0,2))
plt.pie(sizes3, labels=labels3, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

ax4 = plt.subplot2grid((1,4), (0,3))
plt.pie(sizes4, labels=labels4, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

plt.show()

# %%
df_fairface_race = pd.read_excel('Book.ods', 'Fairface-race')

df_race1 = df_fairface_race[df_fairface_race["Dataset"] == "Train data"]
labels1 = df_race1["Race"]
sizes1 = df_race1["generation in percentage"]

df_race2 = df_fairface_race[df_fairface_race["Dataset"] == "DDPM"]
labels2 = df_race2["Race"]
sizes2 = df_race2["generation in percentage"]

df_race3 = df_fairface_race[df_fairface_race["Dataset"] == "DDGAN"]
labels3 = df_race3["Race"]
sizes3 = df_race3["generation in percentage"]

df_race4 = df_fairface_race[df_fairface_race["Dataset"] == "LDM"]
labels4 = df_race4["Race"]
sizes4 = df_race4["generation in percentage"]

color_pallete = ['peachpuff', 'lemonchiffon', 'lavender', 'lavenderblush']

# %%
fig = plt.figure(figsize=(18,10), dpi=1600)
#2 rows 2 columns

ax1 = plt.subplot2grid((1,4), (0,0))
plt.pie(sizes1, labels=labels1, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)
#plt.title('Train')

ax2 = plt.subplot2grid((1,4), (0,1))
plt.pie(sizes2, labels=labels2, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

ax3 = plt.subplot2grid((1,4), (0,2))
plt.pie(sizes3, labels=labels3, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

ax4 = plt.subplot2grid((1,4), (0,3))
plt.pie(sizes4, labels=labels4, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

plt.show()

# %%
df_fairface_race_bal = pd.read_excel('Book.ods', 'FairfaceBal-race')

df_race1 = df_fairface_race_bal[df_fairface_race_bal["Dataset"] == "Train data"]
labels1 = df_race1["Race"]
sizes1 = df_race1["generation in percentage"]

df_race2 = df_fairface_race_bal[df_fairface_race_bal["Dataset"] == "DDPM"]
labels2 = df_race2["Race"]
sizes2 = df_race2["generation in percentage"]

df_race3 = df_fairface_race_bal[df_fairface_race_bal["Dataset"] == "DDGAN"]
labels3 = df_race3["Race"]
sizes3 = df_race3["generation in percentage"]

df_race4 = df_fairface_race_bal[df_fairface_race_bal["Dataset"] == "LDM"]
labels4 = df_race4["Race"]
sizes4 = df_race4["generation in percentage"]

color_pallete = ['peachpuff', 'lemonchiffon', 'lavender', 'lavenderblush']

# %%
fig = plt.figure(figsize=(18,10), dpi=1600)
#2 rows 2 columns

ax1 = plt.subplot2grid((1,4), (0,0))
plt.pie(sizes1, labels=labels1, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)
#plt.title('Train')

ax2 = plt.subplot2grid((1,4), (0,1))
plt.pie(sizes2, labels=labels2, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

ax3 = plt.subplot2grid((1,4), (0,2))
plt.pie(sizes3, labels=labels3, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

ax4 = plt.subplot2grid((1,4), (0,3))
plt.pie(sizes4, labels=labels4, autopct='%1.1f%%', pctdistance=1.2, labeldistance=.7, colors=color_pallete)

plt.show()

# %%
fig, ax = plt.subplots()

start = 0
never = 54
seldom = 43
undecided = 3

ax.broken_barh([(start, never), (never, never+seldom), (never+seldom, never+seldom+undecided)], [10, 9], facecolors=('#6259D8', '#E53F08', '#FDB200'))
ax.set_ylim(5, 15)
ax.set_xlim(0, 100)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks([15, 25])
ax.set_xticks([0, 25, 50, 75, 100])

ax.set_axisbelow(True) 

#ax.set_yticklabels(['Q1'])
ax.grid(axis='x')
ax.text(never-6, 14.5, "54%", fontsize=8)
ax.text((never+seldom)-6, 14.5, "43%", fontsize=8)
ax.text((never+seldom+undecided)+2, 14.5, "3%", fontsize=8)

fig.suptitle('This is title of the chart', fontsize=16)

leg1 = mpatches.Patch(color='#6259D8', label='Never')
leg2 = mpatches.Patch(color='#E53F08', label='Seldom')
leg3 = mpatches.Patch(color='#FDB200', label='Undecided')
ax.legend(handles=[leg1, leg2, leg3], ncol=3)

plt.show()

# %%
White 83
Indian 5
Black 7
Asian 5
